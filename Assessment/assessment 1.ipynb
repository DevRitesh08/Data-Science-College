# %% [markdown]
# # Assessment 1

# %%
import random

print("Guess Game!")
number = random.randint(1, 50)
chances = 5

for i in range(chances):
    guess = int(input("Enter your guess (1-50): "))

    if guess < 1 or guess > 50:
        print("Please think in limits (1-50 only)!")
        continue

    if guess == number:
        print("Congrats! You guessed it right!")
        break
    elif guess > number:
        print("Think of a smaller number")
    else:
        print("Think of a bigger number")
else:
    print(f"Sorry, you lost! The correct number was {number}")
# Out:
# Guess Game!
